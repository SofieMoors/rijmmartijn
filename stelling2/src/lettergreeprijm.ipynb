# %% [markdown]
# ## (Bijna-)identieke rijmwoorden opsporen

# %%
import json
import re
from collections import defaultdict

# Laad de resultaten
with open('../data/rhyme_analysis_by_word.json', 'r', encoding='utf-8') as f:
    results_by_word = json.load(f)

def normalize_vowels(word):
    """Normaliseer klinkers zodat spellingvarianten gelijk worden"""
    w = word.lower()
    
    # Lange klinkers en tweeklanken normaliseren
    # Volgorde is belangrijk: langste eerst!
    
    # oe/ou/oo/oi → o
    w = w.replace('oey', 'oi')
    w = w.replace('oei', 'oi')
    w = w.replace('oe', 'o')
    w = w.replace('ou', 'o')
    w = w.replace('oo', 'o')
    w = w.replace('oi', 'o')
    
    # ee/ei → e
    w = w.replace('eey', 'ei')
    w = w.replace('ee', 'e')
    w = w.replace('ei', 'e')
    w = w.replace('ey', 'e')
    
    # uu/ue/eu → u
    w = w.replace('uu', 'u')
    w = w.replace('ue', 'u')
    w = w.replace('eu', 'u')
    
    # aa/ae/ai → a
    w = w.replace('aa', 'a')
    w = w.replace('ae', 'a')
    w = w.replace('ai', 'a')
    
    # ie → i
    w = w.replace('ie', 'i')
    
    # ij/y → i
    w = w.replace('ij', 'i')
    w = w.replace('y', 'i')
    
    return w

def normalize_consonants(word):
    """Normaliseer medeklinkers zodat spellingvarianten gelijk worden"""
    w = word
    
    # Langste combinaties eerst!
    
    # sch → sc (of s, afhankelijk van context)
    w = w.replace('sch', 'sc')
    
    # gh → g
    w = w.replace('gh', 'g')
    
    # ch → g (of X als je dat wilt behouden)
    w = w.replace('ch', 'g')
    
    # ph → f
    w = w.replace('ph', 'f')
    
    # th → t
    w = w.replace('th', 't')
    
    # qu → kw
    w = w.replace('qu', 'kw')
    
    # ck → k
    w = w.replace('ck', 'k')
    
    # c → k (behalve in combinaties)
    w = w.replace('c', 'k')
    
    # dt → t (aan het eind)
    w = re.sub(r'dt$', 't', w)
    
    # d → t (aan het eind)
    w = re.sub(r'd$', 't', w)
    
    # Dubbele medeklinkers → enkel
    w = re.sub(r'([bcdfghjklmnpqrstvwxz])\1+', r'\1', w)
    
    # v → f (aan het begin, optioneel)
    # w = re.sub(r'^v', 'f', w)
    
    # z → s (aan het begin, optioneel)
    # w = re.sub(r'^z', 's', w)
    
    # nk → ng + k (voor ng-klank)
    # w = w.replace('nk', 'ngk')
    
    # ng behouden als aparte klank
    # (geen verandering nodig)
    
    return w

def normalize_word(word):
    """Normaliseer zowel klinkers als medeklinkers"""
    w = word.lower()
    w = normalize_vowels(w)
    w = normalize_consonants(w)
    return w

def are_nearly_identical(w1, w2):
    """Check of woorden bijna identiek zijn (zelfde stam, spellingvarianten)"""
    w1_lower = w1.lower()
    w2_lower = w2.lower()
    
    # Exact identiek
    if w1_lower == w2_lower:
        return True, 'identical'
    
    # Normaliseer volledig
    w1_norm = normalize_word(w1_lower)
    w2_norm = normalize_word(w2_lower)
    
    # Identiek na normalisatie
    if w1_norm == w2_norm:
        # Bepaal of het een klinker- of medeklinkervariant is
        w1_vowel = normalize_vowels(w1_lower)
        w2_vowel = normalize_vowels(w2_lower)
        
        if w1_vowel == w2_vowel:
            return True, 'consonant_variant'
        else:
            w1_cons = normalize_consonants(w1_lower)
            w2_cons = normalize_consonants(w2_lower)
            if w1_cons == w2_cons:
                return True, 'vowel_variant'
            else:
                return True, 'vowel_and_consonant_variant'
    
    # Eén is prefix van de ander (genormaliseerd)
    if w1_norm.startswith(w2_norm) or w2_norm.startswith(w1_norm):
        if len(w1_norm) != len(w2_norm):
            longer = w1_norm if len(w1_norm) > len(w2_norm) else w2_norm
            shorter = w2_norm if len(w1_norm) > len(w2_norm) else w1_norm
            diff = longer[len(shorter):]
            if diff in ['e', 'en', 's', 'n', 'es', 'ens', 'er', 'ere', 'eren', 'de', 'den', 'te', 'ten']:
                return True, f'suffix_{diff}'
        return True, 'prefix'
    
    # Alleen verschil in suffix (genormaliseerd)
    for suffix in ['e', 'en', 's', 'n', 'es', 'ens', 'er', 'ere', 'eren', 'de', 'den', 'te', 'ten']:
        if w1_norm + suffix == w2_norm or w2_norm + suffix == w1_norm:
            return True, f'suffix_{suffix}'
    
    return False, None

# Zoek identieke en bijna-identieke rijmwoorden binnen dezelfde rijmgroep
identical_rhymes = []
nearly_identical_rhymes = []

# Groepeer per manuscript, sectie, strofe, en rijmletter
for manuscript, words in results_by_word.items():
    # Groepeer woorden per strofe en rijmletter
    groups = defaultdict(list)
    
    for w in words:
        if w['status'] == 'analyzed':
            key = (w['section'], w['strofe'], w['rhyme_letter'])
            groups[key].append(w)
    
    # Check elke groep op identieke/bijna-identieke woorden
    for (section, strofe, rhyme_letter), group_words in groups.items():
        # Vergelijk alle paren
        for i, w1 in enumerate(group_words):
            for j, w2 in enumerate(group_words):
                if i >= j:  # Voorkom dubbele vergelijkingen
                    continue
                
                is_similar, match_type = are_nearly_identical(w1['word'], w2['word'])
                
                if is_similar:
                    result = {
                        'manuscript': manuscript,
                        'section': section,
                        'strofe': strofe,
                        'rhyme_letter': rhyme_letter,
                        'word1': w1['word'],
                        'word2': w2['word'],
                        'word1_normalized': normalize_word(w1['word'].lower()),
                        'word2_normalized': normalize_word(w2['word'].lower()),
                        'vers1_id': w1['vers_id'],
                        'vers2_id': w2['vers_id'],
                        'vers1_pos': w1['vers_pos'],
                        'vers2_pos': w2['vers_pos'],
                        'match_type': match_type
                    }
                    
                    if match_type == 'identical':
                        identical_rhymes.append(result)
                    else:
                        nearly_identical_rhymes.append(result)

# Resultaten
print(f"\n{'='*70}")
print(f"IDENTIEKE RIJMWOORDEN: {len(identical_rhymes)}")
print('='*70)

#for item in identical_rhymes:
 #   print(f"\n{item['manuscript']} - {item['section']} strofe {item['strofe']} ({item['rhyme_letter']}-rijm):")
  #  print(f"  '{item['word1']}' op vers {item['vers1_pos']} ({item['vers1_id']})")
   # print(f"  '{item['word2']}' op vers {item['vers2_pos']} ({item['vers2_id']})")

print(f"\n{'='*70}")
print(f"BIJNA-IDENTIEKE RIJMWOORDEN: {len(nearly_identical_rhymes)}")
print('='*70)

# Groepeer per match_type voor overzichtelijkheid
by_match_type = defaultdict(list)
for item in nearly_identical_rhymes:
    by_match_type[item['match_type']].append(item)

for match_type, items in sorted(by_match_type.items(), key=lambda x: -len(x[1])):
    print(f"\n--- {match_type.upper()} ({len(items)} gevallen) ---")
    for item in items[:15]:  # Toon eerste 15 per type
        print(f"  {item['manuscript']} {item['section']} str.{item['strofe']} ({item['rhyme_letter']}): "
              f"'{item['word1']}' vs '{item['word2']}' "
              f"→ '{item['word1_normalized']}'")
    if len(items) > 15:
        print(f"  ... en {len(items) - 15} meer")

# Save resultaten
with open('identical_rhymes.json', 'w', encoding='utf-8') as f:
    json.dump(identical_rhymes, f, indent=2, ensure_ascii=False)

with open('nearly_identical_rhymes.json', 'w', encoding='utf-8') as f:
    json.dump(nearly_identical_rhymes, f, indent=2, ensure_ascii=False)

print(f"\nIdentieke rijmen opgeslagen in 'identical_rhymes.json'")
print(f"Bijna-identieke rijmen opgeslagen in 'nearly_identical_rhymes.json'")

# Extra: toon voorbeelden per type
print(f"\n{'='*70}")
print("VOORBEELDEN PER TYPE")
print('='*70)

for match_type in ['vowel_variant', 'consonant_variant', 'vowel_and_consonant_variant']:
    variants = [r for r in nearly_identical_rhymes if r['match_type'] == match_type]
    if variants:
        print(f"\n--- {match_type.upper()} ({len(variants)} gevallen) ---")
        for item in variants[:20]:
            print(f"  '{item['word1']}' vs '{item['word2']}' → '{item['word1_normalized']}'")

# Statistieken totaal
print(f"\n{'='*70}")
print("TOTAAL OVERZICHT")
print('='*70)

total_identical = len(identical_rhymes)
total_nearly = len(nearly_identical_rhymes)
total = total_identical + total_nearly

print(f"\nTotaal identieke rijmen: {total_identical}")
print(f"Totaal bijna-identieke rijmen: {total_nearly}")
print(f"Totaal problematische rijmen: {total}")

print(f"\nBreakdown bijna-identiek:")
for match_type, items in sorted(by_match_type.items(), key=lambda x: -len(x[1])):
    print(f"  {match_type}: {len(items)} ({len(items)/total_nearly*100:.1f}%)")
# Out:
# ======================================================================
# IDENTIEKE RIJMWOORDEN: 393
# ======================================================================
#
# ======================================================================
# BIJNA-IDENTIEKE RIJMWOORDEN: 37
# ======================================================================
#
# --- CONSONANT_VARIANT (16 gevallen) ---
#   B M1 str.20 (A): 'woort' vs 'woirt' → 'wort'
#   B M1 str.29 (B): 'ere' vs 'eere' → 'ere'
#   B M2 str.8 (A): 'vairt' vs 'vaert' → 'vart'
#   B M2 str.20 (B): 'woorde' vs 'woirde' → 'worde'
#   B M3 str.26 (A): 'tyden' vs 'tiden' → 'tiden'
#   C M1 str.29 (B): 'eere' vs 'ere' → 'ere'
#   C M3 str.21 (A): 'eere' vs 'ere' → 'ere'
#   D2 M2 str.20 (B): 'woorde' vs 'woerde' → 'worde'
#   F M2 str.3 (A): 'leit' vs 'leyt' → 'let'
#   F M2 str.20 (B): 'woirde' vs 'woorde' → 'worde'
#   F M3 str.25 (A): 'eere' vs 'ere' → 'ere'
#   L M3 str.34 (A): 'gaue' vs 'gaeue' → 'gau'
#   O M2 str.3 (A): 'leit' vs 'leyt' → 'let'
#   O M3 str.17 (A): 'croone' vs 'crone' → 'krone'
#   O M3 str.38 (A): 'smake' vs 'smaeke' → 'smake'
#   ... en 1 meer
#
# --- VOWEL_VARIANT (12 gevallen) ---
#   B M1 str.29 (B): 'eere' vs 'eerre' → 'ere'
#   B M1 str.61 (A): 'sat' vs 'sadt' → 'sat'
#   B M3 str.19 (A): 'ghelike' vs 'gelike' → 'gelike'
#   D M3 str.2 (A): 'gehinge' vs 'gehinghe' → 'gehinge'
#   D2 M2 str.23 (A): 'sat' vs 'sadt' → 'sat'
#   D2 M2 str.23 (A): 'sat' vs 'sadt' → 'sat'
#   F M1 str.53 (B): 'ogen' vs 'oghen' → 'ogen'
#   F M3 str.7 (A): 'mercke' vs 'merke' → 'merke'
#   F M3 str.7 (A): 'mercke' vs 'merke' → 'merke'
#   W M3 str.3 (A): 'doge' vs 'doghe' → 'doge'
#   Z M1 str.53 (B): 'bedrogen' vs 'bedroghen' → 'bedrogen'
#   Z M3 str.3 (A): 'doge' vs 'doghe' → 'doge'
#
# --- SUFFIX_N (4 gevallen) ---
#   A M3 str.2 (A): 'dinghen' vs 'dinghe' → 'dingen'
#   B M1 str.73 (B): 'bederue' vs 'bederuen' → 'bederu'
#   L M1 str.73 (B): 'bederue' vs 'bederuen' → 'bederu'
#   L M3 str.38 (A): 'smaeken' vs 'smaeke' → 'smaken'
#
# --- PREFIX (2 gevallen) ---
#   A M1 str.7 (A): 'lech' vs 'lecht' → 'leg'
#   C M3 str.2 (B): 'een' vs 'engheen' → 'en'
#
# --- SUFFIX_E (2 gevallen) ---
#   A M3 str.33 (A): 'meest' vs 'meeste' → 'mest'
#   B M3 str.17 (A): 'croen' vs 'crone' → 'kron'
#
# --- VOWEL_AND_CONSONANT_VARIANT (1 gevallen) ---
#   B M1 str.29 (B): 'ere' vs 'eerre' → 'ere'
#
# Identieke rijmen opgeslagen in 'identical_rhymes.json'
# Bijna-identieke rijmen opgeslagen in 'nearly_identical_rhymes.json'
#
# ======================================================================
# VOORBEELDEN PER TYPE
# ======================================================================
#
# --- VOWEL_VARIANT (12 gevallen) ---
#   'eere' vs 'eerre' → 'ere'
#   'sat' vs 'sadt' → 'sat'
#   'ghelike' vs 'gelike' → 'gelike'
#   'gehinge' vs 'gehinghe' → 'gehinge'
#   'sat' vs 'sadt' → 'sat'
#   'sat' vs 'sadt' → 'sat'
#   'ogen' vs 'oghen' → 'ogen'
#   'mercke' vs 'merke' → 'merke'
#   'mercke' vs 'merke' → 'merke'
#   'doge' vs 'doghe' → 'doge'
#   'bedrogen' vs 'bedroghen' → 'bedrogen'
#   'doge' vs 'doghe' → 'doge'
#
# --- CONSONANT_VARIANT (16 gevallen) ---
#   'woort' vs 'woirt' → 'wort'
#   'ere' vs 'eere' → 'ere'
#   'vairt' vs 'vaert' → 'vart'
#   'woorde' vs 'woirde' → 'worde'
#   'tyden' vs 'tiden' → 'tiden'
#   'eere' vs 'ere' → 'ere'
#   'eere' vs 'ere' → 'ere'
#   'woorde' vs 'woerde' → 'worde'
#   'leit' vs 'leyt' → 'let'
#   'woirde' vs 'woorde' → 'worde'
#   'eere' vs 'ere' → 'ere'
#   'gaue' vs 'gaeue' → 'gau'
#   'leit' vs 'leyt' → 'let'
#   'croone' vs 'crone' → 'krone'
#   'smake' vs 'smaeke' → 'smake'
#   'oogen' vs 'ogen' → 'ogen'
#
# --- VOWEL_AND_CONSONANT_VARIANT (1 gevallen) ---
#   'ere' vs 'eerre' → 'ere'
#
# ======================================================================
# TOTAAL OVERZICHT
# ======================================================================
#
# Totaal identieke rijmen: 393
# Totaal bijna-identieke rijmen: 37
# Totaal problematische rijmen: 430
#
# Breakdown bijna-identiek:
#   consonant_variant: 16 (43.2%)
#   vowel_variant: 12 (32.4%)
#   suffix_n: 4 (10.8%)
#   prefix: 2 (5.4%)
#   suffix_e: 2 (5.4%)
#   vowel_and_consonant_variant: 1 (2.7%)

# %% [markdown]
# ## Lettergreeprijmen opsporen

# %%
import json
import re
from collections import defaultdict
from tqdm import tqdm

# Laad de data
print("Loading data...")
with open('../data/verse_id_lookup.json', 'r', encoding='utf-8') as f:
    verse_id_lookup = json.load(f)

with open('../data/stresses_restructured.json', 'r', encoding='utf-8') as f:
    stress_data = json.load(f)

with open('../data/rhyme_analysis_by_word.json', 'r', encoding='utf-8') as f:
    results_by_word = json.load(f)

# ============================================================================
# SPECIFIEKE GEVALLEN WAAR 'T' VERWIJDERD MAG WORDEN
# ============================================================================

T_PREFIX_ALLOWED = {
    # beswaert:tswaert en varianten
    ('beswaert', 'tswaert'),
    ('tswaert', 'beswaert'),
    ('verzwairt', 'tzwairt'),
    ('tzwairt', 'verzwairt'),
    ('beswaert', 'tzwairt'),
    ('tzwairt', 'beswaert'),
    ('verzwairt', 'tswaert'),
    ('tswaert', 'verzwairt'),
    # waren:twaren en varianten
    ('waren', 'twaren'),
    ('twaren', 'waren'),
    ('tvaren', 'gheuaren'),
    ('gheuaren', 'tvaren'),
    ('twaeren', 'waren'),
    ('waren', 'twaeren'),
    ('gheuaren', 'twaren'),
    ('twaren', 'gheuaren'),
    ('tvaren', 'waren'),
    ('waren', 'tvaren'),
    ('tvelt', 'gheuelt'),
    ('gheuelt', 'tvelt'),
    ('tfelt', 'gevelt'),
    ('gevelt', 'tfelt'),
    ('tvelt', 'gevelt'),
    ('gevelt', 'tvelt'),
    ('tfelt', 'gheuelt'),
    ('gheuelt', 'tfelt'),
}

# ============================================================================
# HANDMATIGE TOEVOEGINGEN (met specifieke manuscripten)
# ============================================================================

# Format: (section, strofe, vers1, vers2, [lijst van manuscripten waar het WEL geldt, of None voor alle])
MANUAL_ADDITIONS = [
    ('M1', 3, 31, 36, None),  # Alle manuscripten
    ('M1', 8, 96, 99, None),  # Alle manuscripten
    ('M1', 10, 119, 125, ['A', 'B', 'C', 'G', 'O', 'Y']),  # NIET D, F, L
    ('M1', 23, 291, 294, None),  # Alle manuscripten
]

# ============================================================================
# HULPFUNCTIES
# ============================================================================

def get_word_data(word, vers_id=None):
    """Haal syllabified en stresses op voor een woord."""
    word = word.lower().strip()
    
    if vers_id and vers_id in verse_id_lookup:
        entry = verse_id_lookup[vers_id]
        return entry['syllabified'], entry['stresses']
    
    if word in stress_data:
        entry = stress_data[word]
        if isinstance(entry, list):
            return entry[0]['syllabified'], entry[0]['stresses']
        else:
            return entry['syllabified'], entry['stresses']
    
    return None, None

def get_rhyming_part(word, vers_id=None):
    """Haal het rijmende deel op: alle lettergrepen vanaf de laatste klemtoon."""
    syllables, stresses = get_word_data(word, vers_id)
    
    if syllables is None:
        return None
    
    if stresses:
        last_stress = max(stresses)
    else:
        last_stress = -1
    
    rhyming_syllables = syllables[last_stress:]
    return ''.join(rhyming_syllables)

def normalize_for_comparison(s):
    """Normaliseer voor vergelijking (ZONDER 't' verwijdering)."""
    s = s.lower()
    
    s = re.sub(r'^u', 'f', s)  
    s = re.sub(r'u(?=[aeiou])', 'f', s)
    
    # Klinkernormalisatie
    s = s.replace('oey', 'oi').replace('oei', 'oi')
    s = s.replace('oe', 'o').replace('ou', 'o').replace('oo', 'o').replace('oi', 'o')
    s = s.replace('eey', 'ei')
    s = s.replace('ee', 'e').replace('ei', 'e').replace('ey', 'e')
    s = s.replace('uu', 'u').replace('ue', 'u').replace('eu', 'u')
    s = s.replace('aa', 'a').replace('ae', 'a').replace('ai', 'a')
    s = s.replace('ie', 'i').replace('ij', 'i').replace('y', 'i')
    
    # Medeklinkernormalisatie
    s = s.replace('gh', 'g').replace('ch', 'g')
    s = s.replace('ph', 'f').replace('th', 't')
    s = s.replace('ck', 'k')
    
    # v/f normalisatie
    s = s.replace('v', 'f')
    
    # u aan begin → f (want is eigenlijk v)
  
    
    # u voor klinker → f
 
    
    # s/z normalisatie
    s = s.replace('z', 's')
    
    # c voor e/i → s (maar NIET sc → ss, want sc is een aparte klank)
    # We doen c → s alleen als c NIET voorafgegaan wordt door s
    s = re.sub(r'(?<!s)c(?=[ei])', 's', s)
    
    # c in andere gevallen → k
    s = re.sub(r'(?<!s)c', 'k', s)
    
    # Eind-normalisatie
    s = re.sub(r'dt$', 't', s)
    s = re.sub(r'd$', 't', s)
    s = re.sub(r'([bcdfghjklmnpqrstvwxz])\1+', r'\1', s)
    
    # e/en normalisatie aan het eind
    s = re.sub(r'en$', 'e', s)
    
    return s

def normalize_with_t_removal(s):
    """Normaliseer MET 't' verwijdering aan het begin."""
    s = s.lower()
    
    # Verwijder 't aan het begin
    if s.startswith('t') and len(s) > 2:
        s = s[1:]
    
    # Rest van normalisatie
    return normalize_for_comparison(s)

def is_t_prefix_pair(word1, word2):
    """Check of dit een toegestaan paar is voor 't' prefix verwijdering."""
    w1 = word1.lower()
    w2 = word2.lower()
    return (w1, w2) in T_PREFIX_ALLOWED or (w2, w1) in T_PREFIX_ALLOWED

def is_lettergreeprijm(word1, word2, vers_id1=None, vers_id2=None):
    """Check of twee woorden lettergreeprijm vormen."""
    full1 = get_rhyming_part(word1, vers_id1)
    full2 = get_rhyming_part(word2, vers_id2)
    
    if full1 is None or full2 is None:
        return False, None, None, None
    
    # Standaard normalisatie (zonder 't' verwijdering)
    full1_norm = normalize_for_comparison(full1)
    full2_norm = normalize_for_comparison(full2)
    
    if full1_norm == full2_norm:
        return True, full1, full2, full1_norm
    
    # Check of dit een toegestaan 't' prefix paar is
    if is_t_prefix_pair(word1, word2):
        full1_t = normalize_with_t_removal(full1)
        full2_t = normalize_with_t_removal(full2)
        if full1_t == full2_t:
            return True, full1, full2, full1_t
    
    return False, full1, full2, None

# ============================================================================
# ZOEK LETTERGREEPRIJMEN
# ============================================================================

print("\n" + "="*60)
print("ZOEKEN NAAR LETTERGREEPRIJMEN")
print("="*60)

lettergreeprijmen = []

for manuscript, words in tqdm(results_by_word.items(), desc="Manuscripts"):
    groups = defaultdict(list)
    
    for w in words:
        if w['status'] == 'analyzed':
            key = (w['section'], w['strofe'], w['rhyme_letter'])
            groups[key].append(w)
    
    for (section, strofe, rhyme_letter), group_words in groups.items():
        for i, w1 in enumerate(group_words):
            for j, w2 in enumerate(group_words):
                if i >= j:
                    continue
                
                # Skip identieke woorden
                if w1['word'].lower() == w2['word'].lower():
                    continue
                
                is_lg_rijm, full1, full2, normalized = is_lettergreeprijm(
                    w1['word'], w2['word'], 
                    w1['vers_id'], w2['vers_id']
                )
                
                if is_lg_rijm:
                    lettergreeprijmen.append({
                        'manuscript': manuscript,
                        'section': section,
                        'strofe': strofe,
                        'rhyme_letter': rhyme_letter,
                        'word1': w1['word'],
                        'word2': w2['word'],
                        'rhyming_part1': full1,
                        'rhyming_part2': full2,
                        'normalized': normalized,
                        'vers1_id': w1['vers_id'],
                        'vers2_id': w2['vers_id'],
                        'vers1_pos': w1['vers_pos'],
                        'vers2_pos': w2['vers_pos'],
                        'type': 'lettergreeprijm'
                    })

# ============================================================================
# HANDMATIGE TOEVOEGINGEN
# ============================================================================

print("\nHandmatige toevoegingen verwerken...")
for section, strofe, vers1, vers2, allowed_manuscripts in MANUAL_ADDITIONS:
    for manuscript, words in results_by_word.items():
        # Check of dit manuscript is toegestaan
        if allowed_manuscripts is not None and manuscript not in allowed_manuscripts:
            continue
        
        word1_info = None
        word2_info = None
        
        for w in words:
            if w['section'] == section and w['strofe'] == strofe:
                vers_num = int(w['vers_id'].split('_')[-1])
                if vers_num == vers1:
                    word1_info = w
                elif vers_num == vers2:
                    word2_info = w
        
        if word1_info and word2_info:
            # Check of dit paar al bestaat
            exists = False
            for lg in lettergreeprijmen:
                if (lg['vers1_id'] == word1_info['vers_id'] and lg['vers2_id'] == word2_info['vers_id']) or \
                   (lg['vers1_id'] == word2_info['vers_id'] and lg['vers2_id'] == word1_info['vers_id']):
                    exists = True
                    break
            
            if not exists:
                full1 = get_rhyming_part(word1_info['word'], word1_info['vers_id'])
                full2 = get_rhyming_part(word2_info['word'], word2_info['vers_id'])
                
                lettergreeprijmen.append({
                    'manuscript': manuscript,
                    'section': section,
                    'strofe': strofe,
                    'rhyme_letter': word1_info['rhyme_letter'],
                    'word1': word1_info['word'],
                    'word2': word2_info['word'],
                    'rhyming_part1': full1,
                    'rhyming_part2': full2,
                    'normalized': normalize_for_comparison(full1) if full1 else '',
                    'vers1_id': word1_info['vers_id'],
                    'vers2_id': word2_info['vers_id'],
                    'vers1_pos': word1_info['vers_pos'],
                    'vers2_pos': word2_info['vers_pos'],
                    'type': 'lettergreeprijm',
                    'manual_addition': True
                })

print(f"Totaal lettergreeprijmen gevonden: {len(lettergreeprijmen)}")

# Save lettergreeprijmen
with open('alle_lettergreeprijmen.json', 'w', encoding='utf-8') as f:
    json.dump(lettergreeprijmen, f, indent=2, ensure_ascii=False)

print(f"Lettergreeprijmen opgeslagen in 'alle_lettergreeprijmen.json'")

# ============================================================================
# LAAD IDENTICAL RHYMES
# ============================================================================

with open('identical_rhymes.json', 'r', encoding='utf-8') as f:
    identical_rhymes = json.load(f)

for item in identical_rhymes:
    item['type'] = 'identical'

print(f"Totaal identical rhymes: {len(identical_rhymes)}")

# ============================================================================
# UNIEKE LOCATIES ANALYSE
# ============================================================================

def get_vers_number(vers_id):
    return int(vers_id.split('_')[-1])

def get_section(vers_id):
    return vers_id.split('_')[1]

def cluster_all_locations(lettergreep_rhymes, identical_rhymes):
    """Groepeer alle rijmparen in clusters waar verzen overlappen."""
    all_rhymes = []
    
    for item in lettergreep_rhymes:
        all_rhymes.append({
            'verses': {get_vers_number(item['vers1_id']), get_vers_number(item['vers2_id'])},
            'section': get_section(item['vers1_id']),
            'manuscript': item['manuscript'],
            'items': [item],
            'types': {'lettergreeprijm'}
        })
    
    for item in identical_rhymes:
        all_rhymes.append({
            'verses': {get_vers_number(item['vers1_id']), get_vers_number(item['vers2_id'])},
            'section': get_section(item['vers1_id']),
            'manuscript': item['manuscript'],
            'items': [item],
            'types': {'identical'}
        })
    
    # Groepeer per sectie
    by_section = defaultdict(list)
    for rhyme in all_rhymes:
        by_section[rhyme['section']].append(rhyme)
    
    # Merge overlappende clusters per sectie
    merged_clusters = {}
    for section, clusters in by_section.items():
        merged = []
        
        for cluster in clusters:
            found = False
            for existing in merged:
                if cluster['verses'] & existing['verses']:
                    existing['verses'] |= cluster['verses']
                    existing['items'].extend(cluster['items'])
                    existing['types'] |= cluster['types']
                    existing['manuscripts'].add(cluster['manuscript'])
                    found = True
                    break
            
            if not found:
                cluster['manuscripts'] = {cluster['manuscript']}
                merged.append(cluster)
        
        # Herhaal merging
        changed = True
        while changed:
            changed = False
            new_merged = []
            used = set()
            
            for i, c1 in enumerate(merged):
                if i in used:
                    continue
                
                for j, c2 in enumerate(merged):
                    if j <= i or j in used:
                        continue
                    
                    if c1['verses'] & c2['verses']:
                        c1['verses'] |= c2['verses']
                        c1['items'].extend(c2['items'])
                        c1['types'] |= c2['types']
                        c1['manuscripts'] |= c2['manuscripts']
                        used.add(j)
                        changed = True
                
                new_merged.append(c1)
                used.add(i)
            
            merged = new_merged
        
        merged_clusters[section] = merged
    
    return merged_clusters

# Cluster alles
print("\nClusteren van alle rijmen...")
all_clusters = cluster_all_locations(lettergreeprijmen, identical_rhymes)

# ============================================================================
# STATISTIEKEN
# ============================================================================

print(f"\n{'='*80}")
print("UNIEKE LOCATIES ANALYSE")
print('='*80)

total_all = 0
stats_by_section = {}

for section in ['M1', 'M2', 'M3']:
    clusters = all_clusters.get(section, [])
    
    only_lettergreep = sum(1 for c in clusters if c['types'] == {'lettergreeprijm'})
    only_identical = sum(1 for c in clusters if c['types'] == {'identical'})
    both = sum(1 for c in clusters if 'lettergreeprijm' in c['types'] and 'identical' in c['types'])
    
    total_all += len(clusters)
    
    stats_by_section[section] = {
        'total': len(clusters),
        'only_lettergreep': only_lettergreep,
        'only_identical': only_identical,
        'both': both
    }
    
    print(f"\n{section}: {len(clusters)} unieke locaties")
    print(f"  - Alleen lettergreeprijm: {only_lettergreep}")
    print(f"  - Alleen identical: {only_identical}")
    print(f"  - Beide types: {both}")

print(f"\nTOTAAL: {total_all} unieke locaties")

# ============================================================================
# DETAIL OUTPUT
# ============================================================================

print(f"\n{'='*80}")
print("DETAIL PER SECTIE")
print('='*80)

output_data = {
    'total_unique_locations': total_all,
    'by_section': {}
}

for section in ['M1', 'M2', 'M3']:
    clusters = all_clusters.get(section, [])
    clusters_sorted = sorted(clusters, key=lambda x: min(x['verses']))
    
    print(f"\n--- {section} ({len(clusters)} unieke locaties) ---")
    
    section_data = []
    for cluster in clusters_sorted:
        verses = sorted(cluster['verses'])
        types = list(cluster['types'])
        manuscripts = sorted(cluster['manuscripts'])
        
        # Verzamel info
        word_pairs = set()
        identical_words = set()
        
        for item in cluster['items']:
            if item.get('type') == 'lettergreeprijm':
                pair = tuple(sorted([item['word1'].lower(), item['word2'].lower()]))
                word_pairs.add(pair)
            else:
                word = item.get('word') or item.get('word1')
                if word:
                    identical_words.add(word.lower())
        
        verses_str = ':'.join(str(v) for v in verses)
        types_str = '+'.join(sorted(types))
        manuscripts_str = ','.join(manuscripts)
        
        info_parts = []
        if identical_words:
            info_parts.append(f"identical: {', '.join(sorted(identical_words))}")
        if word_pairs:
            pairs_str = '; '.join(f"'{p[0]}':'{p[1]}'" for p in list(word_pairs)[:3])
            info_parts.append(f"lettergreep: {pairs_str}")
        
        print(f"  {section}_{verses_str} [{types_str}]: {' | '.join(info_parts)} (in: {manuscripts_str})")
        
        section_data.append({
            'verses': verses,
            'types': types,
            'identical_words': list(identical_words),
            'lettergreep_pairs': [list(p) for p in word_pairs],
            'manuscripts': manuscripts
        })
    
    output_data['by_section'][section] = {
        'count': len(clusters),
        'statistics': stats_by_section[section],
        'locations': section_data
    }

# ============================================================================
# TELLINGEN PER MANUSCRIPT
# ============================================================================

print(f"\n{'='*80}")
print("TELLINGEN PER MANUSCRIPT")
print('='*80)

# Lettergreeprijmen per manuscript
lg_per_manuscript = defaultdict(lambda: defaultdict(int))
for item in lettergreeprijmen:
    manuscript = item['manuscript']
    section = item['section']
    lg_per_manuscript[manuscript][section] += 1
    lg_per_manuscript[manuscript]['totaal'] += 1

# Identical per manuscript
id_per_manuscript = defaultdict(lambda: defaultdict(int))
for item in identical_rhymes:
    manuscript = item['manuscript']
    section = item['section']
    id_per_manuscript[manuscript][section] += 1
    id_per_manuscript[manuscript]['totaal'] += 1

manuscripts_sorted = sorted(set(list(lg_per_manuscript.keys()) + list(id_per_manuscript.keys())))

print(f"\nLETTERGREEPRIJMEN PER MANUSCRIPT:")
print(f"{'Manuscript':<12} {'M1':>8} {'M2':>8} {'M3':>8} {'Totaal':>10}")
print("-" * 50)

totals_lg = {'M1': 0, 'M2': 0, 'M3': 0, 'totaal': 0}
for ms in manuscripts_sorted:
    m1 = lg_per_manuscript[ms].get('M1', 0)
    m2 = lg_per_manuscript[ms].get('M2', 0)
    m3 = lg_per_manuscript[ms].get('M3', 0)
    tot = lg_per_manuscript[ms]['totaal']
    print(f"{ms:<12} {m1:>8} {m2:>8} {m3:>8} {tot:>10}")
    totals_lg['M1'] += m1
    totals_lg['M2'] += m2
    totals_lg['M3'] += m3
    totals_lg['totaal'] += tot

print("-" * 50)
print(f"{'TOTAAL':<12} {totals_lg['M1']:>8} {totals_lg['M2']:>8} {totals_lg['M3']:>8} {totals_lg['totaal']:>10}")

print(f"\nIDENTICAL RHYMES PER MANUSCRIPT:")
print(f"{'Manuscript':<12} {'M1':>8} {'M2':>8} {'M3':>8} {'Totaal':>10}")
print("-" * 50)

totals_id = {'M1': 0, 'M2': 0, 'M3': 0, 'totaal': 0}
for ms in manuscripts_sorted:
    m1 = id_per_manuscript[ms].get('M1', 0)
    m2 = id_per_manuscript[ms].get('M2', 0)
    m3 = id_per_manuscript[ms].get('M3', 0)
    tot = id_per_manuscript[ms]['totaal']
    print(f"{ms:<12} {m1:>8} {m2:>8} {m3:>8} {tot:>10}")
    totals_id['M1'] += m1
    totals_id['M2'] += m2
    totals_id['M3'] += m3
    totals_id['totaal'] += tot

print("-" * 50)
print(f"{'TOTAAL':<12} {totals_id['M1']:>8} {totals_id['M2']:>8} {totals_id['M3']:>8} {totals_id['totaal']:>10}")

print(f"\nGECOMBINEERD (LETTERGREEP + IDENTICAL):")
print(f"{'Manuscript':<12} {'M1':>8} {'M2':>8} {'M3':>8} {'Totaal':>10}")
print("-" * 50)

totals_comb = {'M1': 0, 'M2': 0, 'M3': 0, 'totaal': 0}
for ms in manuscripts_sorted:
    m1 = lg_per_manuscript[ms].get('M1', 0) + id_per_manuscript[ms].get('M1', 0)
    m2 = lg_per_manuscript[ms].get('M2', 0) + id_per_manuscript[ms].get('M2', 0)
    m3 = lg_per_manuscript[ms].get('M3', 0) + id_per_manuscript[ms].get('M3', 0)
    tot = m1 + m2 + m3
    print(f"{ms:<12} {m1:>8} {m2:>8} {m3:>8} {tot:>10}")
    totals_comb['M1'] += m1
    totals_comb['M2'] += m2
    totals_comb['M3'] += m3
    totals_comb['totaal'] += tot

print("-" * 50)
print(f"{'TOTAAL':<12} {totals_comb['M1']:>8} {totals_comb['M2']:>8} {totals_comb['M3']:>8} {totals_comb['totaal']:>10}")

# Save tellingen
output_tellingen = {
    'lettergreeprijmen': {
        'per_manuscript': {ms: dict(lg_per_manuscript[ms]) for ms in manuscripts_sorted},
        'totals': totals_lg
    },
    'identical_rhymes': {
        'per_manuscript': {ms: dict(id_per_manuscript[ms]) for ms in manuscripts_sorted},
        'totals': totals_id
    },
    'combined': {
        'per_manuscript': {ms: {
            'M1': lg_per_manuscript[ms].get('M1', 0) + id_per_manuscript[ms].get('M1', 0),
            'M2': lg_per_manuscript[ms].get('M2', 0) + id_per_manuscript[ms].get('M2', 0),
            'M3': lg_per_manuscript[ms].get('M3', 0) + id_per_manuscript[ms].get('M3', 0),
            'totaal': lg_per_manuscript[ms]['totaal'] + id_per_manuscript[ms]['totaal']
        } for ms in manuscripts_sorted},
        'totals': totals_comb
    }
}

with open('rijmfouten_per_manuscript.json', 'w', encoding='utf-8') as f:
    json.dump(output_tellingen, f, indent=2, ensure_ascii=False)

print(f"\nTellingen per manuscript opgeslagen in 'rijmfouten_per_manuscript.json'")

# ============================================================================
# SAMENVATTING
# ============================================================================

print(f"\n{'='*80}")
print("SAMENVATTING")
print('='*80)

print(f"\nRuwe data:")
print(f"  Lettergreeprijmen: {len(lettergreeprijmen)} paren")
print(f"  Identical rhymes: {len(identical_rhymes)} paren")
print(f"  Totaal: {len(lettergreeprijmen) + len(identical_rhymes)} paren")

print(f"\nUnieke locaties: {total_all}")
# Out:
# Loading data...
#
# ============================================================
# ZOEKEN NAAR LETTERGREEPRIJMEN
# ============================================================
# Manuscripts: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:01<00:00, 15.62it/s]
# Handmatige toevoegingen verwerken...
# Totaal lettergreeprijmen gevonden: 736
# Lettergreeprijmen opgeslagen in 'alle_lettergreeprijmen.json'
# Totaal identical rhymes: 393
#
# Clusteren van alle rijmen...
#
# ================================================================================
# UNIEKE LOCATIES ANALYSE
# ================================================================================
#
# M1: 95 unieke locaties
#   - Alleen lettergreeprijm: 43
#   - Alleen identical: 29
#   - Beide types: 23
#
# M2: 42 unieke locaties
#   - Alleen lettergreeprijm: 14
#   - Alleen identical: 17
#   - Beide types: 11
#
# M3: 58 unieke locaties
#   - Alleen lettergreeprijm: 23
#   - Alleen identical: 20
#   - Beide types: 15
#
# TOTAAL: 195 unieke locaties
#
# ================================================================================
# DETAIL PER SECTIE
# ================================================================================
#
# --- M1 (95 unieke locaties) ---
#   M1_2:8 [lettergreeprijm]: lettergreep: 'doerstaen':'staen' (in: B)
#   M1_7:11 [lettergreeprijm]: lettergreep: 'ontfaen':'vaen'; 'beuaen':'ontfaen' (in: A,B,C,D,F,G,L,O)
#   M1_14:18 [identical]: identical: dit (in: A,B,C,D,F,G,L,O,Y)
#   M1_31:36 [lettergreeprijm]: lettergreep: 'negheen':'scheen'; 'negeen':'sceen'; 'gheen':'sceen' (in: A,B,C,D,F,G,L,O,Y)
#   M1_41:46 [lettergreeprijm]: lettergreep: 'staen':'verstaen' (in: A)
#   M1_44:47 [lettergreeprijm]: lettergreep: 'bevaen':'ontfaen'; 'beuaen':'ontfaen' (in: A,B,C,D,F,G,O,Y)
#   M1_68:77 [identical]: identical: eere, ere (in: A,B,C,D,F,G,L,O,Y)
#   M1_79:85 [identical]: identical: lecht (in: O)
#   M1_81:87 [lettergreeprijm]: lettergreep: 'creatuere':'natuere'; 'creaturen':'naturen'; 'creatueren':'natuere' (in: A,B,C,D,F,G,Y)
#   M1_94:103 [lettergreeprijm]: lettergreep: 'dochte':'gedochte'; 'dochte':'ghedochte' (in: A,B,C,D,F,G,O,Y)
#   M1_96:99 [lettergreeprijm]: lettergreep: 'engheen':'vtesceen'; 'negeen':'sceen'; 'gheen':'sceen' (in: A,B,C,D,F,G,L,O,Y)
#   M1_105:112 [identical]: identical: was (in: A,B,C,D,F,G,O,Y)
#   M1_111:115 [lettergreeprijm]: lettergreep: 'gelas':'las' (in: Y)
#   M1_118:119:125:128 [identical+lettergreeprijm]: identical: wel | lettergreep: 'duuel':'vel'; 'fel':'vel'; 'duuel':'fel' (in: A,B,C,D,F,G,O,Y)
#   M1_120:130 [lettergreeprijm]: lettergreep: 'betale':'tale'; 'betaele':'taele' (in: A,B,C,D,F,G,O,Y)
#   M1_133:139:142 [lettergreeprijm]: lettergreep: 'auentueren':'natueren'; 'auontueren':'creatueren'; 'auontueren':'natueren' (in: A,B,C,D,F,G,O,Y)
#   M1_146:155 [identical]: identical: saken (in: B)
#   M1_159:162 [identical+lettergreeprijm]: identical: hoeden | lettergreep: 'behoeden':'hoeden' (in: D,F,L,Y)
#   M1_171:173:174:177:179 [identical+lettergreeprijm]: identical: spaert, verswaert | lettergreep: 'mesvaert':'vaert'; 'vaert':'veruaert'; 'mesuaert':'vaert' (in: C,D,F,G,O)
#   M1_186:192 [lettergreeprijm]: lettergreep: 'ghedestrueert':'gheeert' (in: B,C,D,F)
#   M1_196:200 [identical]: identical: wreet (in: D,F,O)
#   M1_199:206 [lettergreeprijm]: lettergreep: 'geleet':'leet'; 'gheleet':'leet'; 'geleidt':'leet' (in: A,B,C,D,F,G,O)
#   M1_201:204 [identical]: identical: plaghen (in: C)
#   M1_224:230 [lettergreeprijm]: lettergreep: 'bestaen':'verstaen'; 'bestane':'verstane' (in: D,F,G,O)
#   M1_243:246 [lettergreeprijm]: lettergreep: 'gewoude':'woude'; 'ghewoude':'woude' (in: A,C,D,F,G,O)
#   M1_249:254 [identical+lettergreeprijm]: identical: woirt, woort | lettergreep: 'woirt':'woort' (in: B,F,O)
#   M1_262:267 [identical]: identical: staen (in: B,C,D,F,G,O)
#   M1_266:273 [lettergreeprijm]: lettergreep: 'eerlijke':'onghelijke'; 'eerlike':'onghelike'; 'dongelike':'eerlike' (in: A,B,C,D,F,G,O)
#   M1_270:271 [identical]: identical: waen (in: G)
#   M1_275:283 [identical]: identical: al (in: A,B)
#   M1_287:296 [identical]: identical: mijn (in: F)
#   M1_291:294 [lettergreeprijm]: lettergreep: 'anschijn':'eyghijn'; 'anschijn':'eygijn'; 'aenscijn':'eyghijn' (in: A,B,C,D,F,G,O)
#   M1_302:312 [lettergreeprijm]: lettergreep: 'geten':'vergeten'; 'gheten':'vergheten' (in: F,G)
#   M1_313:319:323 [lettergreeprijm]: lettergreep: 'instrument':'perlement'; 'instrument':'parlement'; 'instrvment':'perlement' (in: A,B,C,D,F,G,O)
#   M1_321:324 [lettergreeprijm]: lettergreep: 'alrene':'nazarene'; 'nazarene':'reene'; 'nazareene':'reene' (in: A,B,C,F,G,O)
#   M1_334:337 [lettergreeprijm]: lettergreep: 'bastaertdinne':'dinne'; 'bastaerdinne':'dinne'; 'bastardinne':'dinne' (in: A,B,C,D,F,G,O)
#   M1_341:347 [lettergreeprijm]: lettergreep: 'verweerde':'weerde'; 'verwerde':'werde'; 'verwaerde':'waerde' (in: A,D,G,O)
#   M1_353:356 [identical]: identical: gewont (in: G)
#   M1_367:370:377 [identical+lettergreeprijm]: identical: eere | lettergreep: 'eere':'eerre'; 'eere':'ere'; 'eerre':'ere' (in: A,B,C,D,F,G,O)
#   M1_368:371 [lettergreeprijm]: lettergreep: 'doet':'ghedoet' (in: F)
#   M1_395:400 [identical]: identical: ontsprinc (in: A)
#   M1_406:412 [identical]: identical: leuen (in: B)
#   M1_407:414 [identical]: identical: gat (in: O)
#   M1_420:426 [lettergreeprijm]: lettergreep: 'delijt':'ghelijdt'; 'delijt':'gelijdt'; 'ghelijt':'iolijt' (in: D,F,G,Z)
#   M1_430:439 [identical]: identical: vint (in: A,B,C,D,E,F,G,O,Z)
#   M1_447:450 [lettergreeprijm]: lettergreep: 'plecht':'verplecht'; 'plecht':'uerplecht' (in: O,Z)
#   M1_457:463:466 [identical+lettergreeprijm]: identical: verdraget | lettergreep: 'gheuaeght':'vaeght' (in: C,Z)
#   M1_458:464:468 [identical+lettergreeprijm]: identical: verdragen, waghen | lettergreep: 'draghen':'verdraghen' (in: B,E,F,Z)
#   M1_470:475 [identical]: identical: si (in: B)
#   M1_486:488:492 [lettergreeprijm]: lettergreep: 'getrect':'onttrect'; 'getrect':'ontrect'; 'getrect':'trect' (in: A,B,Br,C,D,E,F,G,O,Z)
#   M1_498:501 [identical+lettergreeprijm]: identical: sijn, zijn | lettergreep: 'sijn':'zijn'; 'siin':'ziin' (in: A,B,Br,C,D,E,F,O,Z)
#   M1_500:506 [identical]: identical: spelle, telle (in: A,B,Br,D,E,F,Z)
#   M1_511:512 [lettergreeprijm]: lettergreep: 'bequam':'quam'; 'mesquam':'quam' (in: B,C,D,E,F,G,O,Z)
#   M1_521:528:530 [identical+lettergreeprijm]: identical: telt | lettergreep: 'telt':'vertelt' (in: A,B,C,D,E,F,G,O,Z)
#   M1_524:525 [lettergreeprijm]: lettergreep: 'gevelt':'tfelt'; 'gheuelt':'tvelt' (in: A,G)
#   M1_536:542 [identical+lettergreeprijm]: identical: rijset, riset | lettergreep: 'gheriset':'riset' (in: A,B,C,E,F,G,O)
#   M1_537:540 [identical]: identical: staet (in: A,D,E)
#   M1_548:551:556 [identical+lettergreeprijm]: identical: an | lettergreep: 'began':'gan' (in: A,Br,C,D,E,F,G)
#   M1_552:555:559 [lettergreeprijm]: lettergreep: 'doechtachticheiden':'edelheiden'; 'duechtdachticheden':'edelheden'; 'duechtdachticheden':'heden' (in: A,B,Br,C,D,F,G,O)
#   M1_561:567 [identical]: identical: hout (in: A,F,G,O)
#   M1_575:578:585 [identical+lettergreeprijm]: identical: rijcheden | lettergreep: 'miltheden':'waerhede'; 'miltheden':'rijcheden'; 'milthede':'waerheden' (in: A,B,Br,C,D,F,G,O)
#   M1_599:609 [identical]: identical: nijt (in: Br,F,G)
#   M1_604:607:611 [lettergreeprijm]: lettergreep: 'ewelike':'gelike'; 'ghelike':'jamerlike'; 'ewelike':'jamerlike' (in: A,B,Br,C,D,F,G,H,O)
#   M1_628:632 [lettergreeprijm]: lettergreep: 'gheuoet':'voet' (in: O)
#   M1_642:648 [lettergreeprijm]: lettergreep: 'ontfaen':'vaen' (in: C)
#   M1_678:680:681:683:686 [identical+lettergreeprijm]: identical: tijt, verwijt | lettergreep: 'verwijt':'wijt'; 'uerwijt':'wijt' (in: A,B,Br,C,D,F,G,H,O,Z)
#   M1_679:689 [identical+lettergreeprijm]: identical: oghen | lettergreep: 'ogen':'oogen'; 'ogen':'oghen' (in: A,B,C,F,Z)
#   M1_682:685:688 [identical+lettergreeprijm]: identical: bedroghen | lettergreep: 'doruloghen':'gheloghen'; 'bedrogen':'bedroghen' (in: A,D,O,Z)
#   M1_684:687 [identical+lettergreeprijm]: identical: lijt | lettergreep: 'lijt':'voirlijt' (in: A,B,Br,C,D,F,G,O,Z)
#   M1_691:700 [identical]: identical: pant (in: A,Br,F,G,Z)
#   M1_705:711:715 [identical+lettergreeprijm]: identical: coninghinne | lettergreep: 'dine':'godinne'; 'dinne':'goddinne'; 'dinne':'godinne' (in: A,B,C,D,F,G,O)
#   M1_721:727 [lettergreeprijm]: lettergreep: 'donghestadichede':'dorperhede'; 'dorperhede':'ongestadechhede'; 'dorperhede':'ongestaedichede' (in: A,B,C,D,F,G,L,O)
#   M1_732:735 [identical]: identical: scelt, stelt (in: G,O)
#   M1_750:754 [lettergreeprijm]: lettergreep: 'toeghen':'vertoeghen' (in: O)
#   M1_759:762 [identical]: identical: vaer (in: F)
#   M1_769:771:775 [identical+lettergreeprijm]: identical: behout | lettergreep: 'behout':'hout' (in: A,B,O)
#   M1_770:779:780 [lettergreeprijm]: lettergreep: 'armoede':'vermoede'; 'armoede':'bemoede'; 'beuroede':'vroede' (in: A,B,C,D,F,G,K,L,O)
#   M1_782:788 [identical+lettergreeprijm]: identical: sat, zat | lettergreep: 'sat':'zat'; 'sadt':'sat' (in: A,B,C,D,F,G,K,O)
#   M1_796:799:805:806 [lettergreeprijm]: lettergreep: 'selsiene':'ziene'; 'engiene':'mischiene'; 'tesiene':'zelsiene' (in: A,B,C,D,F,G,K,L,O)
#   M1_798:801 [identical+lettergreeprijm]: identical: vaen | lettergreep: 'anevaen':'vaen'; 'ontfaen':'vaen' (in: A,B,C,D,G,L,O)
#   M1_808:813:814 [identical+lettergreeprijm]: identical: sat, zat | lettergreep: 'gadsat':'sat'; 'sat':'zat'; 'godsat':'sat' (in: A,B,C,D,F,G,K,O)
#   M1_812:815 [lettergreeprijm]: lettergreep: 'oitmoedelike':'onghelike'; 'omoedelike':'onghelike'; 'oetmoedelike':'ongelike' (in: A,B,C,D,F,G,K,O)
#   M1_834:843 [identical]: identical: torment (in: D,F)
#   M1_861:867 [lettergreeprijm]: lettergreep: 'aermoede':'moede'; 'armoede':'moede'; 'aermoeden':'moede' (in: A,B,C,D,F,G,Ge,H,L,O)
#   M1_863:865:866 [identical]: identical: poech, pooch, tooch (in: A,B,F,L)
#   M1_874:883 [identical]: identical: sneuen (in: A,B)
#   M1_878:882 [identical]: identical: smal (in: O)
#   M1_898:905:908 [lettergreeprijm]: lettergreep: 'miscien':'opzien'; 'vpsien':'zien'; 'opsien':'sien' (in: C,G,L,O)
#   M1_899:901 [lettergreeprijm]: lettergreep: 'dien':'ontdien' (in: D)
#   M1_924:927 [identical]: identical: vint (in: B,D,F,G,H)
#   M1_930:933 [lettergreeprijm]: lettergreep: 'bewint':'wijnt'; 'bewijnt':'wijnt'; 'bewint':'wint' (in: A,B,C,D,F,G,L,O)
#   M1_937:944 [lettergreeprijm]: lettergreep: 'adaem':'dam'; 'adam':'dam' (in: B,C,D,F,H,L)
#   M1_938:946 [lettergreeprijm]: lettergreep: 'nam':'vernam' (in: A,B,C,D,F,G,O)
#   M1_939:942:949 [identical+lettergreeprijm]: identical: bederuen | lettergreep: 'besteruen':'steruen'; 'bederue':'bederuen' (in: A,B,C,D,F,G,L,O)
#   M1_963:967:969:973 [identical+lettergreeprijm]: identical: hout | lettergreep: 'behout':'hout'; 'dbehout':'hout'; 'behout':'houdt' (in: A,B,C,D,F,G,Ge,H,L,O)
#
# --- M2 (42 unieke locaties) ---
#   M2_5:10 [identical]: identical: ghewin (in: O)
#   M2_17:21 [lettergreeprijm]: lettergreep: 'anquam':'mesquam'; 'anquam':'misquam'; 'mesquaem':'quaem' (in: A,B,D,F,G,L)
#   M2_22:26 [lettergreeprijm]: lettergreep: 'beleeden':'verleeden' (in: G)
#   M2_31:34 [identical+lettergreeprijm]: identical: leit, leyt | lettergreep: 'leit':'leyt' (in: A,B,D,F,G,L,O)
#   M2_54:56 [lettergreeprijm]: lettergreep: 'gedaen':'onderdaen'; 'daen':'gedaen'; 'ghedaen':'onderdaen' (in: A,B,D,F,G,L,O)
#   M2_57:62 [lettergreeprijm]: lettergreep: 'gaen':'vergaen' (in: A,B,D,F,G,L,O)
#   M2_58:65 [lettergreeprijm]: lettergreep: 'gewinnen':'verwinnen'; 'ghewinnen':'verwinnen' (in: A,B,F,G,L,O)
#   M2_69:72 [identical]: identical: twint (in: L)
#   M2_80:83:85:88:89 [identical+lettergreeprijm]: identical: bant, cant | lettergreep: 'bewant':'triwant'; 'bewant':'truwant'; 'bant':'verbant' (in: A,B,F,G,H,L,O)
#   M2_81:91 [identical]: identical: leuen (in: O)
#   M2_92:96:98:99 [identical+lettergreeprijm]: identical: vaert, waert, wart | lettergreep: 'vaert':'vairt'; 'begart':'gart'; 'begaert':'gaert' (in: A,B,D,F,G,O)
#   M2_101:102 [lettergreeprijm]: lettergreep: 'beswaert':'tswaert'; 'tzwairt':'verzwairt' (in: B,D)
#   M2_105:114 [identical]: identical: niet (in: A)
#   M2_106:111 [lettergreeprijm]: lettergreep: 'biedt':'gebiedt'; 'biet':'ghebiet' (in: A,B,Br,D,F,G,O)
#   M2_109:115 [identical+lettergreeprijm]: identical: siet | lettergreep: 'siet':'ziet' (in: A,Br,D,O)
#   M2_119:122 [identical]: identical: scat (in: A,F,G,O)
#   M2_120:123 [identical]: identical: broeder (in: G)
#   M2_126:129 [identical]: identical: loeder (in: Br)
#   M2_131:137 [identical]: identical: getal, ghetal (in: A,B,Br,D,F,G,O)
#   M2_132:138 [identical]: identical: al (in: G)
#   M2_145:147 [identical]: identical: bant (in: A,Br,F,O)
#   M2_146:155 [lettergreeprijm]: lettergreep: 'binden':'ontbinden' (in: B)
#   M2_148:151 [identical]: identical: hant (in: A,B,Br,D,F,G,H,O)
#   M2_164:166 [identical]: identical: becoort (in: F)
#   M2_170:177:179 [identical+lettergreeprijm]: identical: couent | lettergreep: 'testament':'torment' (in: A,B,Br,D,F,G,O)
#   M2_187:190 [identical]: identical: dan (in: B,O)
#   M2_204:207 [lettergreeprijm]: lettergreep: 'ghestade':'stade' (in: B)
#   M2_212:213:218 [identical+lettergreeprijm]: identical: macht | lettergreep: 'macht':'vermacht' (in: A,F)
#   M2_223:226 [lettergreeprijm]: lettergreep: 'salomoen':'sermoen'; 'sermoen':'zalomoen'; 'salomon':'sermoen' (in: A,B,Br,D,D2,F,G,O)
#   M2_225:231 [lettergreeprijm]: lettergreep: 'doen':'ondoen'; 'doen':'ontdoen' (in: A,B,Br,D,F,G,O)
#   M2_236:241:245 [identical+lettergreeprijm]: identical: bestiet | lettergreep: 'bediet':'diet' (in: A,B,Br,F,G,O)
#   M2_249:255:257:258 [identical+lettergreeprijm]: identical: gewes, ghetes, ghewes | lettergreep: 'gheles':'les' (in: A,B,Br,D,D2,F,H,O)
#   M2_250:256 [identical+lettergreeprijm]: identical: woerde, woorde, worde | lettergreep: 'woerde':'woorde'; 'woirde':'woorde' (in: A,B,Br,D,D2,F,G,O)
#   M2_278:284 [identical]: identical: bant (in: B)
#   M2_282:285 [lettergreeprijm]: lettergreep: 'beginne':'coninginne'; 'beghinne':'coninginne'; 'beghinne':'coninghinne' (in: A,B,D,D2,F,G,H,O)
#   M2_290:291:294:297 [identical+lettergreeprijm]: identical: sadt, sat, zat | lettergreep: 'godsat':'zat'; 'sadt':'sat' (in: A,B,Br,D,D2,F,G,O)
#   M2_292:298 [lettergreeprijm]: lettergreep: 'creatueren':'natueren'; 'creaturen':'naturen' (in: A,Br,D,F,G,O)
#   M2_302:312 [identical]: identical: leuen (in: B,D,D2,F,G,Z)
#   M2_303:310 [identical]: identical: gereet (in: Z)
#   M2_304:306 [lettergreeprijm]: lettergreep: 'beheet':'heet' (in: A)
#   M2_320:322 [identical+lettergreeprijm]: identical: schoot, scoet, scoot | lettergreep: 'medeschoot':'schoot' (in: A,B,D,D2,F,G,O,Z)
#   M2_326:332 [identical]: identical: waer (in: A,Br,E,G,O,Z)
#
# --- M3 (58 unieke locaties) ---
#   M3_15:20:21:23 [identical+lettergreeprijm]: identical: gehinge | lettergreep: 'gehinge':'gehinghe'; 'dinghe':'dinghen'; 'singhe':'zinghe' (in: A,Br,D,F,O)
#   M3_31:36 [identical+lettergreeprijm]: identical: doeghe, doge | lettergreep: 'doge':'doghe'; 'doge':'gedoge' (in: Br,F,G,O,W,Z)
#   M3_40:47 [identical]: identical: bouken (in: O)
#   M3_41:43 [lettergreeprijm]: lettergreep: 'besouken':'soeken' (in: B)
#   M3_67:75 [lettergreeprijm]: lettergreep: 'beginne':'coninginne'; 'beghinne':'coninghinne'; 'beginne':'coninghinne' (in: A,B,C,D,F,G,O,W,Z)
#   M3_79:80:82:88 [identical+lettergreeprijm]: identical: mercke, mercken, merke | lettergreep: 'mercke':'merke'; 'gewerke':'werke'; 'gemercke':'mercke' (in: A,B,C,D,F,G,O,W,Z)
#   M3_87:90 [identical]: identical: dwinc (in: F,Z)
#   M3_97:100:103 [identical+lettergreeprijm]: identical: heet | lettergreep: 'steet':'weersteet' (in: B,O)
#   M3_98:102 [identical]: identical: eere (in: O)
#   M3_105:111 [lettergreeprijm]: lettergreep: 'draghen':'ghedraghen'; 'draghen':'onghedraghen' (in: A,C)
#   M3_122:125 [lettergreeprijm]: lettergreep: 'cleynen':'verclenen' (in: D)
#   M3_126:129 [identical]: identical: gheureest (in: C)
#   M3_149:156 [lettergreeprijm]: lettergreep: 'besie':'zie' (in: C)
#   M3_150:151 [lettergreeprijm]: lettergreep: 'conde':'oirconde'; 'conde':'orconde' (in: A,B,C,E,F,G,O,W)
#   M3_162:169 [lettergreeprijm]: lettergreep: 'gheseit':'ontseit' (in: B,O)
#   M3_165:168 [identical+lettergreeprijm]: identical: godheyt | lettergreep: 'godheyt':'menscheyt'; 'godheit':'menschelecheit'; 'godheit':'menschlicheit' (in: A,B,C,D,F,G,O,W)
#   M3_186:190 [lettergreeprijm]: lettergreep: 'mogenthede':'onledechede'; 'moghenthede':'onleidicheide'; 'moghenthede':'onledichede' (in: A,B,C,D,F,G,O,W)
#   M3_199:206 [identical]: identical: bescreuen (in: A,B,C,D,F,G,O,W)
#   M3_200:205 [lettergreeprijm]: lettergreep: 'anbleuen':'bleuen' (in: O)
#   M3_204:208 [identical]: identical: stranc (in: G,W)
#   M3_209:215 [identical+lettergreeprijm]: identical: croene, crone | lettergreep: 'crone':'croone' (in: A,C,D,F,G,O,W)
#   M3_222:232 [lettergreeprijm]: lettergreep: 'beghinne':'coninginne'; 'beginne':'coninginne'; 'beghinne':'coninghinne' (in: A,B,C,D,F,G,O,W)
#   M3_224:234 [identical]: identical: ghehoort (in: O)
#   M3_235:238 [lettergreeprijm]: lettergreep: 'hemelrijke':'rijke'; 'hemelrike':'rike'; 'hemelrike':'rijcke' (in: B,C,D,F,G,O,W)
#   M3_236:242:244 [lettergreeprijm]: lettergreep: 'ewelike':'gelike'; 'eewelike':'gelike'; 'ewelijke':'ghelijke' (in: B,C,D,F,G,O,W)
#   M3_243:247 [identical]: identical: meest (in: G,W)
#   M3_248:251:252 [lettergreeprijm]: lettergreep: 'benedien':'gedien'; 'ghebenedijen':'ghedijen'; 'benedien':'ghedien' (in: B,C,O,W)
#   M3_267:270:271 [identical+lettergreeprijm]: identical: eere, ere | lettergreep: 'eere':'ere'; 'emmermeere':'meere'; 'emmermeerre':'mere' (in: C,D,F,G,O,W)
#   M3_278:283 [lettergreeprijm]: lettergreep: 'doomen':'verdomen' (in: D)
#   M3_282:286 [lettergreeprijm]: lettergreep: 'blent':'verblent' (in: C)
#   M3_287:293 [lettergreeprijm]: lettergreep: 'gheladen':'verladen' (in: A)
#   M3_300:303 [identical]: identical: male (in: A)
#   M3_301:304 [identical]: identical: sale, zale (in: G,O,W)
#   M3_302:305:308:311:312 [identical+lettergreeprijm]: identical: bint, kint, twint | lettergreep: 'bekint':'kint' (in: A,D,G,O,W)
#   M3_313:314:317:320:322 [identical+lettergreeprijm]: identical: eere, ere, here | lettergreep: 'eere':'ere'; 'emmermere':'mere'; 'emmermeere':'meere' (in: A,B,C,D,F,G,O,W)
#   M3_315:318 [lettergreeprijm]: lettergreep: 'godheit':'menschelicheyt'; 'godheit':'menschlicheit'; 'godheyt':'menschelicheyt' (in: A,B,C,D,F,G,O,W)
#   M3_326:329 [identical]: identical: besniden (in: D)
#   M3_327:332 [identical+lettergreeprijm]: identical: tiden, tijden | lettergreep: 'tiden':'tyden' (in: A,B,C,D,F,G,O,W,Y)
#   M3_352:353:362 [identical+lettergreeprijm]: identical: waren | lettergreep: 'gheuaren':'tvaren'; 'twaren':'waren' (in: A,B,C,D,F,G,L,O,W,Y)
#   M3_367:376 [identical]: identical: bloet (in: A,B,C,D,F,G,L,O,W)
#   M3_368:372:374 [identical]: identical: hande (in: A,B,C)
#   M3_380:383:386 [lettergreeprijm]: lettergreep: 'moghentheit':'salicheit'; 'menschelecheit':'mogentheit'; 'menschelicheit':'zaelicheit' (in: A,B,C,D,F,G,O,W)
#   M3_392:397:400 [lettergreeprijm]: lettergreep: 'persone':'soene'; 'persone':'sone'; 'persone':'zone' (in: A,B,C,D,F,G,L,O,W)
#   M3_399:402 [identical]: identical: volleest (in: L)
#   M3_404:405 [lettergreeprijm]: lettergreep: 'natuere':'scriftuere'; 'nature':'scrifture'; 'nature':'screfture' (in: A,B,C,D,G,L,O)
#   M3_417:426 [identical]: identical: meeste, neeste (in: B,F,O)
#   M3_419:429 [identical+lettergreeprijm]: identical: sijn, zijn | lettergreep: 'sijn':'zijn' (in: A,B,C,G,O,W)
#   M3_430:434 [identical+lettergreeprijm]: identical: gaue | lettergreep: 'gaeue':'gaue' (in: A,C,D,F,G,L,O,W)
#   M3_431:433 [identical]: identical: haue (in: A)
#   M3_436:439 [identical]: identical: graue (in: A,B,C,D,F,G,O,W)
#   M3_444:447 [identical]: identical: inne, jnne (in: B,C,D,F,G,O,W)
#   M3_448:451 [lettergreeprijm]: lettergreep: 'menschelicheyt':'onsalicheyt'; 'menschelecheit':'onsalecheit'; 'menschelicheit':'onsalicheit' (in: A,B,C,D,F,G,L,O,W)
#   M3_449:453 [lettergreeprijm]: lettergreep: 'beghinne':'coninginne'; 'beginne':'coninginne'; 'beghinne':'coninghinne' (in: A,B,C,D,F,G,L,O,W)
#   M3_456:457:463 [identical+lettergreeprijm]: identical: waren | lettergreep: 'twaeren':'waren'; 'uerwaren':'waren'; 'twaren':'waren' (in: A,B,C,D,F,G,L,W)
#   M3_460:466 [identical]: identical: sparen (in: D,F,O)
#   M3_486:488:489 [identical+lettergreeprijm]: identical: smake | lettergreep: 'gerake':'rake'; 'smaeke':'smake'; 'smaeke':'smaeken' (in: B,D,F,G,L,O,W,Y)
#   M3_487:493 [identical]: identical: droemt (in: A)
#   M3_495:505 [lettergreeprijm]: lettergreep: 'celle':'ghezelle'; 'celle':'gheselle'; 'celle':'geselle' (in: A,B,C,D,F,G,L,O,W)
#
# ================================================================================
# TELLINGEN PER MANUSCRIPT
# ================================================================================
#
# LETTERGREEPRIJMEN PER MANUSCRIPT:
# Manuscript         M1       M2       M3     Totaal
# --------------------------------------------------
# A                  52       14       20         86
# B                  56       19       26        101
# Br                 11        5        0         16
# C                  57        0       23         80
# D                  52       12       18         82
# D2                  0        5        0          5
# E                   6        0        1          7
# F                  55       15       25         95
# G                  52       14       23         89
# Ge                  2        0        0          2
# H                   5        2        0          7
# K                   3        0        0          3
# L                  12        5        9         26
# O                  51       13       25         89
# W                   0        0       22         22
# Y                  13        0        1         14
# Z                  10        0        2         12
# --------------------------------------------------
# TOTAAL            437      104      195        736
#
# IDENTICAL RHYMES PER MANUSCRIPT:
# Manuscript         M1       M2       M3     Totaal
# --------------------------------------------------
# A                  24       13       15         52
# B                  19        8       11         38
# Br                  6       10        2         18
# C                  12        0       12         24
# D                  20       10       17         47
# D2                  0        4        0          4
# E                   6        1        0          7
# F                  25       11       15         51
# G                  20       13       14         47
# Ge                  0        0        0          0
# H                   3        3        0          6
# K                   2        0        0          2
# L                   5        3        2         10
# O                  21       13       21         55
# W                   0        0       13         13
# Y                   4        0        2          6
# Z                   7        4        2         13
# --------------------------------------------------
# TOTAAL            174       93      126        393
#
# GECOMBINEERD (LETTERGREEP + IDENTICAL):
# Manuscript         M1       M2       M3     Totaal
# --------------------------------------------------
# A                  76       27       35        138
# B                  75       27       37        139
# Br                 17       15        2         34
# C                  69        0       35        104
# D                  72       22       35        129
# D2                  0        9        0          9
# E                  12        1        1         14
# F                  80       26       40        146
# G                  72       27       37        136
# Ge                  2        0        0          2
# H                   8        5        0         13
# K                   5        0        0          5
# L                  17        8       11         36
# O                  72       26       46        144
# W                   0        0       35         35
# Y                  17        0        3         20
# Z                  17        4        4         25
# --------------------------------------------------
# TOTAAL            611      197      321       1129
#
# Tellingen per manuscript opgeslagen in 'rijmfouten_per_manuscript.json'
#
# ================================================================================
# SAMENVATTING
# ================================================================================
#
# Ruwe data:
#   Lettergreeprijmen: 736 paren
#   Identical rhymes: 393 paren
#   Totaal: 1129 paren
#
# Unieke locaties: 195
